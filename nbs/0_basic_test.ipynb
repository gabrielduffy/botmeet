# %%
# !pip install pandas
# !pip install vexa-client

# %%
import os
import sys
import pandas as pd
from IPython.display import clear_output, display
import time
from dotenv import load_dotenv

load_dotenv()

# Add the testing directory to the path
sys.path.append('../testing')

from core import create_user_client, request_bot,get_transcript

from vexa_client.vexa import parse_url,VexaClient

BASE_URL= 'http://localhost:8056'
ADMIN_API_TOKEN = os.getenv('ADMIN_API_TOKEN')
TEST_USER_API_KEY = os.getenv('TEST_USER_API_KEY')

print(BASE_URL)
# Out:
# http://localhost:8056

# %% [markdown]
# ### basic functionality test:
# 1. create user
# 2. set webhook (optional)
# 3. request bot
# 4. get meetings
# 5. get trasncript
# 6. update_bot_config
# 7. stop bot
# 8. delete_meeting

# %%
ADMIN_API_TOKEN = 'token'

# %%
client = create_user_client(base_url=BASE_URL,admin_api_key=ADMIN_API_TOKEN)
# Out:
# DEBUG: Making POST request to http://localhost:8056/admin/users
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-Admin-API-Key': 'token'}
# DEBUG: Params: None
# DEBUG: JSON data: {'email': '321281@example.com', 'name': 'test', 'max_concurrent_bots': 1}
# DEBUG: Response status: 201
# DEBUG: Response headers: {'date': 'Thu, 15 Jan 2026 15:35:50 GMT, Thu, 15 Jan 2026 15:35:51 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '146', 'content-type': 'application/json'}
# DEBUG: Response content: {"email":"321281@example.com","name":"test","image_url":null,"max_concurrent_bots":1,"data":{},"id":189,"created_at":"2026-01-15T15:35:51.704032"}...
#
# DEBUG: Making POST request to http://localhost:8056/admin/users/189/tokens
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-Admin-API-Key': 'token'}
# DEBUG: Params: None
# DEBUG: JSON data: None
# DEBUG: Response status: 201
# DEBUG: Response headers: {'date': 'Thu, 15 Jan 2026 15:35:50 GMT, Thu, 15 Jan 2026 15:35:51 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '117', 'content-type': 'application/json'}
# DEBUG: Response content: {"user_id":189,"id":231,"token":"sew4yAAeBKwts7RNeDni010NXUZ3j1xNJcNNCfbh","created_at":"2026-01-15T15:35:51.717169"}...

# %%
#client = VexaClient(base_url=BASE_URL,api_key=TEST_USER_API_KEY)

# %%
client._api_key
# Out:
# 'sew4yAAeBKwts7RNeDni010NXUZ3j1xNJcNNCfbh'

# %%
#optional: set webhook
# obtain webhook url from https://webhook-test.com/

client.set_webhook_url("https://webhook-test.com/89d8111238baa40e7778559c7989cc60")

# webhook will be called with every bot status update
# Out:
# DEBUG: Making PUT request to http://localhost:8056/user/webhook
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 'sew4yAAeBKwts7RNeDni010NXUZ3j1xNJcNNCfbh'}
# DEBUG: Params: None
# DEBUG: JSON data: {'webhook_url': 'https://webhook-test.com/89d8111238baa40e7778559c7989cc60'}
# DEBUG: Response status: 200
# DEBUG: Response headers: {'date': 'Thu, 15 Jan 2026 15:35:54 GMT, Thu, 15 Jan 2026 15:35:55 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '219', 'content-type': 'application/json'}
# DEBUG: Response content: {"email":"321281@example.com","name":"test","image_url":null,"max_concurrent_bots":1,"data":{"webhook_url":"https://webhook-test.com/89d8111238baa40e7778559c7989cc60"},"id":189,"created_at":"2026-01-15T15:35:51.704032"}...
# {'email': '321281@example.com',
#  'name': 'test',
#  'image_url': None,
#  'max_concurrent_bots': 1,
#  'data': {'webhook_url': 'https://webhook-test.com/89d8111238baa40e7778559c7989cc60'},
#  'id': 189,
#  'created_at': '2026-01-15T15:35:51.704032'}

# %%
# create meeting with meet.new or in you MS Teams profile

# %%
# Google Meet:

meeting_url="https://meet.google.com/dvo-ubvq-fdc"
platform, native_meeting_id, passcode = parse_url(meeting_url)

# %%
#MS Teams:

meeting_url="https://teams.live.com/meet/93686988660257?p=MAjYtMwG3BT8kazbmo"
platform, native_meeting_id, passcode = parse_url(meeting_url)

# %%
client._api_key
# Out:
# 'sew4yAAeBKwts7RNeDni010NXUZ3j1xNJcNNCfbh'

# %%
request_bot(client,platform, native_meeting_id, passcode=passcode, bot_name="Vexa bot", language='ru')


# # now admit the bot to the meeting
# Out:
# DEBUG: Making POST request to http://localhost:8056/bots
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 'sew4yAAeBKwts7RNeDni010NXUZ3j1xNJcNNCfbh'}
# DEBUG: Params: None
# DEBUG: JSON data: {'platform': 'google_meet', 'native_meeting_id': 'dvo-ubvq-fdc', 'bot_name': 'Vexa bot', 'language': 'ru', 'task': 'transcribe'}
# DEBUG: Response status: 201
# DEBUG: Response headers: {'date': 'Thu, 15 Jan 2026 15:44:07 GMT, Thu, 15 Jan 2026 15:44:07 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '384', 'content-type': 'application/json'}
# DEBUG: Response content: {"id":208,"user_id":189,"platform":"google_meet","native_meeting_id":"dvo-ubvq-fdc","constructed_meeting_url":"https://meet.google.com/dvo-ubvq-fdc","status":"requested","bot_container_id":"7b655863742e101222ebfac66151b0d63eee46d4262cddfc8b8d120517c83211","start_time":null,"end_time":null,"data":{},"created_at":"2026-01-15T15:44:07.477345","updated_at":"2026-01-15T15:44:07.493571"}...
# {'id': 208,
#  'user_id': 189,
#  'platform': 'google_meet',
#  'native_meeting_id': 'dvo-ubvq-fdc',
#  'constructed_meeting_url': 'https://meet.google.com/dvo-ubvq-fdc',
#  'status': 'requested',
#  'bot_container_id': '7b655863742e101222ebfac66151b0d63eee46d4262cddfc8b8d120517c83211',
#  'start_time': None,
#  'end_time': None,
#  'data': {},
#  'created_at': '2026-01-15T15:44:07.477345',
#  'updated_at': '2026-01-15T15:44:07.493571'}

# %%
# speak and run this to see transcripts pooled for 10 seconds

get_transcript(client,platform, native_meeting_id,tail=3,duration=10)
# Out:
# DEBUG: Making GET request to http://localhost:8056/transcripts/google_meet/dvo-ubvq-fdc
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 'sew4yAAeBKwts7RNeDni010NXUZ3j1xNJcNNCfbh'}
# DEBUG: Params: {}
# DEBUG: JSON data: None
# DEBUG: Response status: 500
# DEBUG: Response headers: {'date': 'Thu, 15 Jan 2026 15:46:07 GMT, Thu, 15 Jan 2026 15:46:06 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '21', 'content-type': 'text/plain; charset=utf-8'}
# DEBUG: Response content: Internal Server Error...
# HTTP Error 500 for GET http://localhost:8056/transcripts/google_meet/dvo-ubvq-fdc: Internal Server Error

# %%
client.stop_bot(platform=platform,native_meeting_id=native_meeting_id)
# Out:
# DEBUG: Making DELETE request to http://localhost:8056/bots/google_meet/dvo-ubvq-fdc
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 'sew4yAAeBKwts7RNeDni010NXUZ3j1xNJcNNCfbh'}
# DEBUG: Params: None
# DEBUG: JSON data: None
# DEBUG: Response status: 202
# DEBUG: Response headers: {'date': 'Thu, 15 Jan 2026 15:44:00 GMT, Thu, 15 Jan 2026 15:44:00 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '59', 'content-type': 'application/json'}
# DEBUG: Response content: {"message":"Stop request accepted and is being processed."}...
# {'message': 'Stop request accepted and is being processed.'}

# %%
client.delete_meeting(platform=platform,native_meeting_id=native_meeting_id)
# Out:
# DEBUG: Making DELETE request to http://localhost:8056/meetings/google_meet/fov-ggxa-anx
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 'SKQRqy4riSZdmTd62ttObu7VylhMOkQUhbqkyD8v'}
# DEBUG: Params: None
# DEBUG: JSON data: None
# DEBUG: Response status: 200
# DEBUG: Response headers: {'date': 'Thu, 18 Dec 2025 15:43:55 GMT, Thu, 18 Dec 2025 15:43:55 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '86', 'content-type': 'application/json'}
# DEBUG: Response content: {"message":"Meeting google_meet/fov-ggxa-anx transcripts deleted and data anonymized"}...
# {'message': 'Meeting google_meet/fov-ggxa-anx transcripts deleted and data anonymized'}

# %%
# after deletion transcripts removed from the database

get_transcript(client,platform, native_meeting_id,tail=50,duration=10)

# %%
# after deletion meeting record anonimized  


meetings = client.get_meetings()
meetings

# %%
client.stop_bot(platform='teams',native_meeting_id='93686988660257')

# %%
import pandas as pd

df = pd.DataFrame(meetings)

# %%
df[~df['status'].isin(['completed','failed'])]
