# %%
import sys
sys.path.append('../testing')

from core import create_user_client, request_bot,get_transcript

# %%
import os
import sys
import pandas as pd
from IPython.display import clear_output, display
import time

# Add the testing directory to the path
sys.path.append('../testing')

from core import create_user_client, request_bot,get_transcript

from vexa_client.vexa import parse_url,VexaClient

# Cell 1: Imports
import websockets, httpx, json

from vexa_client.vexa import parse_url, VexaClient

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
client = create_user_client(base_url=os.getenv('BASE_URL'),admin_api_key=os.getenv('ADMIN_API_TOKEN'))
# Out:
# DEBUG: Making POST request to http://localhost:18056/admin/users
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-Admin-API-Key': 'token'}
# DEBUG: Params: None
# DEBUG: JSON data: {'email': '75399@example.com', 'name': 'test', 'max_concurrent_bots': 1}
# DEBUG: Response status: 201
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 14:52:12 GMT, Thu, 27 Nov 2025 14:52:11 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '146', 'content-type': 'application/json'}
# DEBUG: Response content: {"email":"75399@example.com","name":"test","image_url":null,"max_concurrent_bots":1,"data":{},"id":1578,"created_at":"2025-11-27T14:52:12.865651"}...
#
# DEBUG: Making POST request to http://localhost:18056/admin/users/1578/tokens
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-Admin-API-Key': 'token'}
# DEBUG: Params: None
# DEBUG: JSON data: None
# DEBUG: Response status: 201
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 14:52:12 GMT, Thu, 27 Nov 2025 14:52:11 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '119', 'content-type': 'application/json'}
# DEBUG: Response content: {"user_id":1578,"id":1628,"token":"TSTCitVbx4FYUKj5BiwENxbPqftWYQZcwVzavqBQ","created_at":"2025-11-27T14:52:12.877964"}...

# %%
# Google Meet:

meeting_url="https://meet.google.com/fov-ggxa-anx"
platform, native_meeting_id, passcode = parse_url(meeting_url)

# %%
#MS Teams:

meeting_url="https://teams.live.com/meet/9313542088192?p=FGfOc6hXyfj7UsDqW8"
platform, native_meeting_id, passcode = parse_url(meeting_url)

# %%
request_bot(client,platform, native_meeting_id, passcode=passcode, bot_name="Vexa bot", language='en')
# Out:
# DEBUG: Making POST request to http://localhost:18056/bots
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 'TSTCitVbx4FYUKj5BiwENxbPqftWYQZcwVzavqBQ'}
# DEBUG: Params: None
# DEBUG: JSON data: {'platform': 'google_meet', 'native_meeting_id': 'fov-ggxa-anx', 'bot_name': 'Vexa bot', 'language': 'en', 'task': 'transcribe'}
# DEBUG: Response status: 201
# DEBUG: Response headers: {'date': 'Thu, 27 Nov 2025 14:52:21 GMT, Thu, 27 Nov 2025 14:52:20 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '386', 'content-type': 'application/json'}
# DEBUG: Response content: {"id":1886,"user_id":1578,"platform":"google_meet","native_meeting_id":"fov-ggxa-anx","constructed_meeting_url":"https://meet.google.com/fov-ggxa-anx","status":"requested","bot_container_id":"7c280d5aa7c9ffc62895c962e36fe6d986ea0c267d25ad0d523832d91db5aa09","start_time":null,"end_time":null,"data":{},"created_at":"2025-11-27T14:52:21.777108","updated_at":"2025-11-27T14:52:21.787052"}...
# {'id': 1886,
#  'user_id': 1578,
#  'platform': 'google_meet',
#  'native_meeting_id': 'fov-ggxa-anx',
#  'constructed_meeting_url': 'https://meet.google.com/fov-ggxa-anx',
#  'status': 'requested',
#  'bot_container_id': '7c280d5aa7c9ffc62895c962e36fe6d986ea0c267d25ad0d523832d91db5aa09',
#  'start_time': None,
#  'end_time': None,
#  'data': {},
#  'created_at': '2025-11-27T14:52:21.777108',
#  'updated_at': '2025-11-27T14:52:21.787052'}

# %%
import pandas as pd

# %%
msgs = []

# Cell 4: Connect WebSocket (runs until stopped)
async with websockets.connect(os.getenv('WS_URL'), additional_headers=[("X-API-Key", client._api_key)]) as ws:
    await ws.send(json.dumps({"action": "subscribe", "meetings": [{"platform": platform, "native_id": native_meeting_id}]}))
    
    async for frame in ws:
        msg = json.loads(frame)
        print(f"Received: {msg.get('type')}")
        msgs.append(msg)
        
        if msg['type'] == 'transcript.mutable':
            display(msg['payload']['segments'])
        else:
            print(msg)
# Out:
# Received: subscribed
# {'type': 'subscribed', 'meetings': [{'platform': 'google_meet', 'native_id': 'fov-ggxa-anx'}]}
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[8], line 7
#       4 async with websockets.connect(os.getenv('WS_URL'), additional_headers=[("X-API-Key", client._api_key)]) as ws:
#       5     await ws.send(json.dumps({"action": "subscribe", "meetings": [{"platform": platform, "native_id": native_meeting_id}]}))
# ----> 7     async for frame in ws:
#       8         msg = json.loads(frame)
#       9         print(f"Received: {msg.get('type')}")
#
# File ~/anaconda3/envs/vexa/lib/python3.11/site-packages/websockets/asyncio/connection.py:242, in Connection.__aiter__(self)
#     240 try:
#     241     while True:
# --> 242         yield await self.recv()
#     243 except ConnectionClosedOK:
#     244     return
#
# File ~/anaconda3/envs/vexa/lib/python3.11/site-packages/websockets/asyncio/connection.py:303, in Connection.recv(self, decode)
#     256 """
#     257 Receive the next message.
#     258
#    (...)
#     300
#     301 """
#     302 try:
# --> 303     return await self.recv_messages.get(decode)
#     304 except EOFError:
#     305     pass
#
# File ~/anaconda3/envs/vexa/lib/python3.11/site-packages/websockets/asyncio/messages.py:159, in Assembler.get(self, decode)
#     154 # Locking with get_in_progress prevents concurrent execution
#     155 # until get() fetches a complete message or is canceled.
#     157 try:
#     158     # First frame
# --> 159     frame = await self.frames.get(not self.closed)
#     160     self.maybe_resume()
#     161     assert frame.opcode is OP_TEXT or frame.opcode is OP_BINARY
#
# File ~/anaconda3/envs/vexa/lib/python3.11/site-packages/websockets/asyncio/messages.py:51, in SimpleQueue.get(self, block)
#      49 self.get_waiter = self.loop.create_future()
#      50 try:
# ---> 51     await self.get_waiter
#      52 finally:
#      53     self.get_waiter.cancel()
#
# CancelledError:

# %%
client.stop_bot(platform=platform,native_meeting_id=native_meeting_id)
# Out:
# {'message': 'Stop request accepted and is being processed.'}
